# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
"I chose the **Refresh / Content Opportunity Scoring** lane. This lane focuses on identifying which content pages should be reviewed first based on search and engagement metrics. I selected this lane because it helps content teams prioritize their work instead of manually checking every page. Using data-driven recommendations can make the review process more efficient and support better decision-making."

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
'''My research question is: **Can we identify which content pages should be reviewed first for refresh using search and engagement data?**

This work supports the decision of deciding which pages should be reviewed first. A content manager or SEO specialist can use the recommendations to prioritize pages for updates.

If the recommendation is wrong, time may be spent reviewing a page that does not need attention. If an important page is missed, its performance may continue to decline, resulting in lost traffic and engagement.'''

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2
#       3 df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ y] Every section above is filled — markdown thinking AND the code that backs it
# - [ y] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ y] No client names, URLs, or private queries anywhere
# - [ y] My claims use careful words: observed, measured, directional, decision-support
# - [ y] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
